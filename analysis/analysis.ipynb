# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/trackFeatures.csv")
df.insert(loc=0, column='Playlist Name', value=df['playlistName'])
df.insert(loc=1, column='Track Name', value=df['trackName'])
df = df.drop(columns=['Unnamed: 0','trackName', 'playlistName'])
df
# Out:
#                           Playlist Name            Track Name  danceability  \
# 0     albümden albüme atlamak zor geldi        The Way I Feel         0.508
# 1     albümden albüme atlamak zor geldi  Chase The Night Away         0.473
# 2     albümden albüme atlamak zor geldi                Thread         0.576
# 3     albümden albüme atlamak zor geldi         Stupid Things         0.571
# 4     albümden albüme atlamak zor geldi                Phases         0.481
# ...                                 ...                   ...           ...
# 1687                    Discover Weekly            Babylon...         0.383
# 1688                    Discover Weekly                 Riots         0.662
# 1689                    Discover Weekly                 BLOOD         0.497
# 1690                    Discover Weekly                  room         0.506
# 1691                    Discover Weekly         Swimming Pool         0.714
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.781    0    -6.919     1       0.0544       0.01680
# 1      0.687    2    -8.186     1       0.0253       0.15900
# 2      0.351    8   -11.418     1       0.0273       0.42900
# 3      0.585    4    -8.260     1       0.1150       0.30600
# 4      0.663   11    -7.945     1       0.0278       0.00427
# ...      ...  ...       ...   ...          ...           ...
# 1687   0.722    4    -6.925     0       0.0638       0.03920
# 1688   0.514    5    -6.469     1       0.0380       0.00848
# 1689   0.825    8    -4.638     0       0.0821       0.00310
# 1690   0.492    2   -10.136     1       0.0281       0.00373
# 1691   0.897    6    -5.469     0       0.0376       0.01260
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1190   0.3500  143.971  audio_features
# 1             0.000000    0.1130   0.5700  175.953  audio_features
# 2             0.000189    0.1040   0.1790  105.962  audio_features
# 3             0.000000    0.1750   0.6180   81.045  audio_features
# 4             0.000002    0.0632   0.7010  181.923  audio_features
# ...                ...       ...      ...      ...             ...
# 1687          0.778000    0.0995   0.0371  149.922  audio_features
# 1688          0.003840    0.2840   0.3330  125.004  audio_features
# 1689          0.004960    0.0905   0.2350   88.712  audio_features
# 1690          0.000000    0.1040   0.0749   82.486  audio_features
# 1691          0.901000    0.0706   0.8890  119.979  audio_features
#
#                           id                                   uri  \
# 0     18mAggfWhdX9vcR4B5DwY3  spotify:track:18mAggfWhdX9vcR4B5DwY3
# 1     4UzRgkkgKbtnPbz3hBhyvS  spotify:track:4UzRgkkgKbtnPbz3hBhyvS
# 2     0jtCa3XLLrofXAuh3dQzy7  spotify:track:0jtCa3XLLrofXAuh3dQzy7
# 3     6MmTICUGiQ0raoV9xqaKLn  spotify:track:6MmTICUGiQ0raoV9xqaKLn
# 4     0H2igpX2q1sQw4BD9nsSe7  spotify:track:0H2igpX2q1sQw4BD9nsSe7
# ...                      ...                                   ...
# 1687  08on2wzs5D8ccY4oRrMR7G  spotify:track:08on2wzs5D8ccY4oRrMR7G
# 1688  0pkYeE8R4SZ4vb3aG9OemM  spotify:track:0pkYeE8R4SZ4vb3aG9OemM
# 1689  2odJRoZ0Bx3aHvNa8hpNrD  spotify:track:2odJRoZ0Bx3aHvNa8hpNrD
# 1690  0lSj0NVDG8UzdSzyhEs8vP  spotify:track:0lSj0NVDG8UzdSzyhEs8vP
# 1691  3BMqVk2NJbH4fxf84e8kDC  spotify:track:3BMqVk2NJbH4fxf84e8kDC
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/18mAggfWhdX9...
# 1     https://api.spotify.com/v1/tracks/4UzRgkkgKbtn...
# 2     https://api.spotify.com/v1/tracks/0jtCa3XLLrof...
# 3     https://api.spotify.com/v1/tracks/6MmTICUGiQ0r...
# 4     https://api.spotify.com/v1/tracks/0H2igpX2q1sQ...
# ...                                                 ...
# 1687  https://api.spotify.com/v1/tracks/08on2wzs5D8c...
# 1688  https://api.spotify.com/v1/tracks/0pkYeE8R4SZ4...
# 1689  https://api.spotify.com/v1/tracks/2odJRoZ0Bx3a...
# 1690  https://api.spotify.com/v1/tracks/0lSj0NVDG8Uz...
# 1691  https://api.spotify.com/v1/tracks/3BMqVk2NJbH4...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/18mA...       246160
# 1     https://api.spotify.com/v1/audio-analysis/4UzR...       243173
# 2     https://api.spotify.com/v1/audio-analysis/0jtC...       292253
# 3     https://api.spotify.com/v1/audio-analysis/6MmT...       229373
# 4     https://api.spotify.com/v1/audio-analysis/0H2i...       216760
# ...                                                 ...          ...
# 1687  https://api.spotify.com/v1/audio-analysis/08on...       257464
# 1688  https://api.spotify.com/v1/audio-analysis/0pkY...       298160
# 1689  https://api.spotify.com/v1/audio-analysis/2odJ...       194157
# 1690  https://api.spotify.com/v1/audio-analysis/0lSj...       216702
# 1691  https://api.spotify.com/v1/audio-analysis/3BMq...       325852
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1687               4
# 1688               4
# 1689               4
# 1690               4
# 1691               4
#
# [1692 rows x 20 columns]

# %%
fig = plt.figure(figsize = (15, 10))
playlists = df['Playlist Name'].unique() 
means = df.groupby('Playlist Name').mean()
plt.bar(playlists, means['danceability'], color ='red')
 
plt.xlabel("User Playlists")
plt.xticks(rotation=90)
plt.ylabel("Danceability")
plt.title("Playlists / Danceability")
plt.savefig("danceability.png")
plt.show()
# Out:
# C:\Users\husey\AppData\Local\Temp\ipykernel_8720\3068355094.py:10: UserWarning: Glyph 12349 (\N{PART ALTERNATION MARK}) missing from current font.
#   plt.savefig("danceability.png")
# C:\Users\husey\anaconda3\envs\spoTI\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12349 (\N{PART ALTERNATION MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
